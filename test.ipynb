# %%
from tokenizer.tokenizer import *

# %%
tokenizer = Tokenizer.from_files(
    vocab_path="data/gpt2_vocab.json", merges_path="data/gpt2_merges.txt", special_tokens=["<|endoftext|>"]
)

encoded_ids = tokenizer.encode("Lets' play with Tokenizer!😄 👌 💰<|endoftext|>")
print(encoded_ids)
decoded_text = tokenizer.decode(encoded_ids)
print(decoded_text)
# Out:
# [43, 1039, 6, 711, 351, 29130, 7509, 0, 47249, 226, 50169, 234, 12520, 240, 108, 50256]
# Lets' play with Tokenizer!😄 👌 💰<|endoftext|>

# %%
list(tokenizer.vocab.items())[-1]
# Out:
# (50256, b'<|endoftext|>')

# %%
tokenizer.special_tokens
# Out:
# {'<|endoftext|>': b'<|endoftext|>'}
